# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohithtechis/Forex_pred/blob/main/Forex_usd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/forex_usd_data.csv')
data.head()
# Out:
#   date(y-m-d)  Argentine Peso  ...  British Pound  Venezuelan Bolivar
# 0  2011-01-01          3.9690  ...       0.640553                 4.3
# 1  2011-01-02          3.9690  ...       0.641067                 4.3
# 2  2011-01-03          3.9735  ...       0.645615                 4.3
# 3  2011-01-04          3.9710  ...       0.641558                 4.3
# 4  2011-01-05          3.9715  ...       0.645308                 4.3
#
# [5 rows x 54 columns]

# %%
data.corr()
# Out:
#                        Argentine Peso  ...  Venezuelan Bolivar
# Argentine Peso               1.000000  ...            0.534086
# Australian Dollar            0.607657  ...            0.121758
# Bahraini Dinar              -0.296066  ...           -0.102348
# Botswana Pula                0.658752  ...            0.193467
# Brazilian Real               0.898519  ...            0.374777
# Bruneian Dollar              0.428402  ...            0.065219
# Bulgarian Lev                0.372276  ...            0.029402
# Canadian Dollar              0.521065  ...            0.069346
# Chilean Peso                 0.783328  ...            0.265407
# Chinese Yuan Renminbi        0.480869  ...           -0.038427
# Colombian Peso               0.824553  ...            0.337215
# Croatian Kuna                0.354934  ...            0.027454
# Czech Koruna                 0.268466  ...           -0.026809
# Danish Krone                 0.368444  ...            0.023322
# ...

# %%
data=data.drop(['Bahraini Dinar','Hong Kong Dollar','Icelandic Krona','Israeli Shekel','South Korean Won','Kuwaiti Dinar','Omani Rial',	'Qatari Riyal', 'Saudi Arabian Riyal', 'Singapore Dollar',  'Swiss Franc',  'Taiwan New Dollar', 'Thai Baht',  'Emirati Dirham',  'Venezuelan Bolivar'],axis=1)

# %%
data.columns   #Libyan Dinar. Omani Rial	Qatari Riyal. Saudi Arabian Riyal. Singapore Dollar  Swiss Franc.  Taiwan New Dollar. Thai Baht.  Emirati Dirham.  Venezuelan Bolivar
# Out:
# Index(['date(y-m-d)', 'Argentine Peso', 'Australian Dollar', 'Botswana Pula',
#        'Brazilian Real', 'Bruneian Dollar', 'Bulgarian Lev', 'Canadian Dollar',
#        'Chilean Peso', 'Chinese Yuan Renminbi', 'Colombian Peso',
#        'Croatian Kuna', 'Czech Koruna', 'Danish Krone', 'Euro',
#        'Hungarian Forint', 'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial',
#        'Japanese Yen', 'Kazakhstani Tenge', 'Libyan Dinar',
#        'Malaysian Ringgit', 'Mauritian Rupee', 'Mexican Peso',
#        'Nepalese Rupee', 'New Zealand Dollar', 'Norwegian Krone',
#        'Pakistani Rupee', 'Philippine Peso', 'Polish Zloty',
#        'Romanian New Leu', 'Russian Ruble', 'South African Rand',
#        'Sri Lankan Rupee', 'Swedish Krona', 'Trinidadian Dollar',
#        'Turkish Lira', 'British Pound'],
#       dtype='object')

# %%
data.head()
# Out:
#   date(y-m-d)  Argentine Peso  ...  Turkish Lira  British Pound
# 0  2011-01-01          3.9690  ...      1.537400       0.640553
# 1  2011-01-02          3.9690  ...      1.537400       0.641067
# 2  2011-01-03          3.9735  ...      1.557411       0.645615
# 3  2011-01-04          3.9710  ...      1.547801       0.641558
# 4  2011-01-05          3.9715  ...      1.543853       0.645308
#
# [5 rows x 39 columns]

# %%
data.rename(columns = {'date(y-m-d)': 'Date'}, inplace = True)
data.head()
# Out:
#          Date  Argentine Peso  ...  Turkish Lira  British Pound
# 0  2011-01-01          3.9690  ...      1.537400       0.640553
# 1  2011-01-02          3.9690  ...      1.537400       0.641067
# 2  2011-01-03          3.9735  ...      1.557411       0.645615
# 3  2011-01-04          3.9710  ...      1.547801       0.641558
# 4  2011-01-05          3.9715  ...      1.543853       0.645308
#
# [5 rows x 39 columns]

# %%
from datetime import datetime
data.Date=pd.to_datetime(data.Date )
data.info()
data['Month']=pd.DatetimeIndex(data['Date']).month
data['Year']=pd.DatetimeIndex(data['Date']).year
data['tday']=pd.DatetimeIndex(data['Date']).day
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3979 entries, 0 to 3978
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   3979 non-null   datetime64[ns]
#  1   Argentine Peso         3979 non-null   float64
#  2   Australian Dollar      3979 non-null   float64
#  3   Botswana Pula          3979 non-null   float64
#  4   Brazilian Real         3979 non-null   float64
#  5   Bruneian Dollar        3979 non-null   float64
#  6   Bulgarian Lev          3979 non-null   float64
#  7   Canadian Dollar        3979 non-null   float64
#  8   Chilean Peso           3979 non-null   float64
#  9   Chinese Yuan Renminbi  3979 non-null   float64
#  10  Colombian Peso         3979 non-null   float64
#  11  Croatian Kuna          3979 non-null   float64
#  12  Czech Koruna           3979 non-null   float64
#  13  Danish Krone           3979 non-null   float64
# ...

# %%
data=data.drop(['Date'],axis=1)

# %%
sns.boxplot(data['Argentine Peso'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Argentine Peso'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Argentine Peso'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Argentine Peso'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Argentine Peso']<up_lim]
data=data[data['Argentine Peso']>low_lim]
# Out:
# low limit: -34.940273499999996
# upper limit: 81.02325450000001

# %%
sns.boxplot(data['Indian Rupee'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Indian Rupee'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Indian Rupee'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Indian Rupee'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Indian Rupee']<up_lim]
data=data[data['Indian Rupee']>low_lim]
# Out:
# low limit: 51.60346424999999
# upper limit: 80.27325825000001

# %%
sns.boxplot(data['Indonesian Rupiah'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Indonesian Rupiah'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Indonesian Rupiah'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Indonesian Rupiah'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Indonesian Rupiah']<up_lim]
data=data[data['Indonesian Rupiah']>low_lim]
# Out:
# low limit: 11981.643793750003
# upper limit: 15474.139475749997

# %%
sns.boxplot(data['Japanese Yen'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Japanese Yen'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Japanese Yen'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Japanese Yen'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Japanese Yen']<up_lim]
data=data[data['Japanese Yen']>low_lim]
# Out:
# low limit: 98.49538874999996
# upper limit: 122.11916675000003

# %%
sns.boxplot(data['Kazakhstani Tenge'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Kazakhstani Tenge'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Kazakhstani Tenge'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Kazakhstani Tenge'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Kazakhstani Tenge']<up_lim]
data=data[data['Kazakhstani Tenge']>low_lim]
# Out:
# low limit: -107.61075499999998
# upper limit: 668.896709

# %%
sns.boxplot(data['Libyan Dinar'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Libyan Dinar'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Libyan Dinar'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Libyan Dinar'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Libyan Dinar']<up_lim]
data=data[data['Libyan Dinar']>low_lim]
# Out:
# low limit: 1.3061045000000002
# upper limit: 1.4556164999999999

# %%
sns.boxplot(data['Malaysian Ringgit'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Malaysian Ringgit'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Malaysian Ringgit'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Malaysian Ringgit'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Malaysian Ringgit']<up_lim]
data=data[data['Malaysian Ringgit']>low_lim]
# Out:
# low limit: 2.12112225
# upper limit: 5.43433225

# %%
sns.boxplot(data['Mauritian Rupee'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Mauritian Rupee'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Mauritian Rupee'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Mauritian Rupee'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Mauritian Rupee']<up_lim]
data=data[data['Mauritian Rupee']>low_lim]
# Out:
# low limit: 25.399895250000018
# upper limit: 42.200061249999976

# %%
sns.boxplot(data['Mexican Peso'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Mexican Peso'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Mexican Peso'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Mexican Peso'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Mexican Peso']<up_lim]
data=data[data['Mexican Peso']>low_lim]
# Out:
# low limit: 5.645976000000006
# upper limit: 27.50781599999999

# %%
sns.boxplot(data['Nepalese Rupee'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Nepalese Rupee'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Nepalese Rupee'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Nepalese Rupee'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Nepalese Rupee']<up_lim]
data=data[data['Nepalese Rupee']>low_lim]
# Out:
# low limit: 81.53621325
# upper limit: 130.65569525

# %%
sns.boxplot(data['New Zealand Dollar'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['New Zealand Dollar'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['New Zealand Dollar'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['New Zealand Dollar'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['New Zealand Dollar']<up_lim]
data=data[data['New Zealand Dollar']>low_lim]
# Out:
# low limit: 0.98106475
# upper limit: 1.8115587499999999

# %%
sns.boxplot(data['Norwegian Krone'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Norwegian Krone'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Norwegian Krone'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Norwegian Krone'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Norwegian Krone']<up_lim]
data=data[data['Norwegian Krone']>low_lim]
# Out:
# low limit: 7.286371999999999
# upper limit: 9.562052000000001

# %%
sns.boxplot(data['Philippine Peso'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Philippine Peso'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Philippine Peso'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Philippine Peso'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Philippine Peso']<up_lim]
data=data[data['Philippine Peso']>low_lim]
# Out:
# low limit: 35.26413650000002
# upper limit: 60.46376449999998

# %%
sns.boxplot(data['Romanian New Leu'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = np.percentile(data['Romanian New Leu'], 25, interpolation = 'midpoint')  
Q2 = np.percentile(data['Romanian New Leu'], 50, interpolation = 'midpoint')  
Q3 = np.percentile(data['Romanian New Leu'], 75, interpolation = 'midpoint')     
IQR = Q3 - Q1 
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
print('low limit:', low_lim) 
print('upper limit:', up_lim)

data=data[data['Romanian New Leu']<up_lim]
data=data[data['Romanian New Leu']>low_lim]
# Out:
# low limit: 2.885452250000001
# upper limit: 4.933882249999999

# %%
data.columns
# Out:
# Index(['Argentine Peso', 'Australian Dollar', 'Botswana Pula',
#        'Brazilian Real', 'Bruneian Dollar', 'Bulgarian Lev', 'Canadian Dollar',
#        'Chilean Peso', 'Chinese Yuan Renminbi', 'Colombian Peso',
#        'Croatian Kuna', 'Czech Koruna', 'Danish Krone', 'Euro',
#        'Hungarian Forint', 'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial',
#        'Japanese Yen', 'Kazakhstani Tenge', 'Libyan Dinar',
#        'Malaysian Ringgit', 'Mauritian Rupee', 'Mexican Peso',
#        'Nepalese Rupee', 'New Zealand Dollar', 'Norwegian Krone',
#        'Pakistani Rupee', 'Philippine Peso', 'Polish Zloty',
#        'Romanian New Leu', 'Russian Ruble', 'South African Rand',
#        'Sri Lankan Rupee', 'Swedish Krona', 'Trinidadian Dollar',
#        'Turkish Lira', 'British Pound', 'Month', 'Year', 'tday'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
train, test=train_test_split(data,test_size=0.30)

# %%
X_train=train.drop(['Indian Rupee'],axis=1)
y_train=train['Indian Rupee']
X_test=test.drop(['Indian Rupee'],axis=1)
y_test=test['Indian Rupee']

# %%
print('Dimension of X_train dataframe:',X_train.shape)
print('Dimension of y_train dataframe:',y_train.shape)
print('Dimension of X_test dataframe:',X_test.shape)
print('Dimension of y_test dataframe:',y_test.shape)
# Out:
# Dimension of X_train dataframe: (1359, 40)
# Dimension of y_train dataframe: (1359,)
# Dimension of X_test dataframe: (583, 40)
# Dimension of y_test dataframe: (583,)

# %%
from sklearn.linear_model import LinearRegression
ln_reg= LinearRegression()
ln_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score

y_pred = ln_reg.predict(X_test)
print("Accuracy: ", ln_reg.score(X_test,y_test))
print('Mean Absolute Error of linear regression:',mean_absolute_error(y_pred, y_test))
print('Mean Square Error of linear regression:', mean_squared_error(y_pred, y_test))
print('R_Squared Score of linear regression:', r2_score(y_pred, y_test))
# Out:
# Accuracy:  0.9947948805438731
# Mean Absolute Error of linear regression: 0.1754410252303011
# Mean Square Error of linear regression: 0.06404384630086069
# R_Squared Score of linear regression: 0.9947772646618965

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import confusion_matrix
rfcl = RandomForestRegressor(max_depth = 5, min_samples_leaf=5)
rfcl = rfcl.fit(X_train, y_train)
test_pred = rfcl.predict(X_test)
rfcl_score=rfcl.score(X_test , y_test)
print("The Random forest model accuracy is {}".format(rfcl_score))
# Out:
# The Random forest model accuracy is 0.9970893626800593
